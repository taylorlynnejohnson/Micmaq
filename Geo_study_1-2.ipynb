# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, shutil

from general import *
from generation_stm import *
from storage_stm import *
from system_stm import *
from loaddata import calculate_greenhouse_load
from one_D_model import *

from radial_thermocline import radial_thermocline
from estimate_thermocline import estimate_thermocline
from estimate_insul_thickness import estimate_min_insulation_thickness
from create_simulation_history import create_simulation_history

from datetime import datetime, timedelta
import matplotlib.dates as mdates

# %%
# get load data
current_dir = os.getcwd()
original_weather_file = "C:\\Users\\tljohn\\Desktop\\RPB Micmaq\\code\\presque_isle_main_tmy.csv"

num_copies = 1
Kfiles = []
# creating multiple copies of the original weather file
for i in range(num_copies):
    new_file = os.path.join(current_dir, f'presque_isle_main_tmy_{i}.csv')
    shutil.copyfile(original_weather_file, new_file)
    Kfiles.append(new_file)
weather_files = Kfiles
greenhouse_load = calculate_greenhouse_load(weather_files)
ambient_temps = greenhouse_load['T_amb']
T_greenhouse = greenhouse_load['T_greenhouse']
greenhouse_load = greenhouse_load[['NetLoad_MW']]
ambient_temps = ambient_temps[1]
greenhouse_load_arr = greenhouse_load.to_numpy()
greenhouse_load_arr = greenhouse_load_arr.flatten()
date_range = pd.date_range(start='2033-01-01 00:30:00', periods=len(greenhouse_load_arr), freq='h')
greenhouse_load = pd.DataFrame({'load_MW': greenhouse_load_arr}, index=date_range)
greenhouse_load.index.name = 'Date/time'

ambient_temps = pd.DataFrame(ambient_temps, index=greenhouse_load.index, columns=['T_amb'])
ambient_temps.index.name = 'Date/time'
# Out:
# Total Q_net for the year: -287.74 MWh
# c:\Users\tljohn\Desktop\RPB Micmaq\code\loaddata.py:123: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start='2023-01-01', periods=num_hours, freq=f'{timestep_hours}H')
# C:\Users\tljohn\AppData\Local\Temp\ipykernel_12848\2119950351.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ambient_temps = ambient_temps[1]

# %%
# TEA system setup
ratio_MW2acres = {'SAT': 0.24, 'fixed': 0.35}
pv_type = 'fixed'
pv_dc2ac = 1.2 
POI_limit = None  
analysis_period = 25  
ITC = 0.3  

# Setup Site and Systems
NSTTF_site = Site('NSTTF', Weather_Data(Kfiles), -7, POI_limit=POI_limit)
power_block = 0.2 # MW
PV_capacity_AC = 0.1 
PV_capacity_DC = PV_capacity_AC * pv_dc2ac  
ASGARD_PV = PV_System(
    name='ASGARD_PV',
    site=NSTTF_site,
    capacity_MW_DC=PV_capacity_DC,
    PV_array_type=pv_type,
    PV_tilt=30,
    PV_azimuth=180,
    ratio_DC2AC=pv_dc2ac,
    off_grid_operation=False,
    power_priority_load_MW_AC=None
)

TES_capacity_e = 1.1 # MWh
resistive_charge_rate = PV_capacity_DC 

ASGARD_TES = TES_System_STM(
    name='ASGARD_TES',
    site=NSTTF_site,
    capacity_MWh_t=TES_capacity_e / 0.98,
    power_rating_MW_e=power_block,
    power_minimum_MW_e=0,
    efficiency_rating_t2e=0.98,
    percent_discharge_depth=100,
    percent_heat_loss_daily=1,
    charge_rate_CSP_MW_t=0,
    charge_efficiency_t2TES=1,
    charge_rate_resistive_MW_e=resistive_charge_rate,
    charge_efficiency_e2TES=0.98,
    systems_charging=['ASGARD_PV'],
    start_full=False,
    off_grid_operation=True,
    DOE_2030_targets=False
)

systems = [ASGARD_PV, ASGARD_TES]
NSTTF = System(
    load_MW=greenhouse_load,
    systems_load_order=systems,
    analysis_period=analysis_period,
    ITC=ITC
)
tea_timeseries = NSTTF.timeseries
# Out:
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:483: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.09483041435734925' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,'fuel_to_load_MWh_th'] = unmet_load_MW
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:298: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0010174585077886119' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,pv.name+'_to_load_MWh_e'] = pv2l
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:398: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0010174585077886119' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,pv.site.name+'_POI_MW'] = pv_poi
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:371: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.055446209391082524' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,pv.name+'_to_'+tes.name+'_MWh_e'] = pv2tes
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:384: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.05433728520326087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,tes.name+'_MWh_t'] = tes_MWh_t
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:244: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2640535501358697e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,tes.name+'_thermal_loss_MWh_t'] = tloss
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:438: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.013580730226782831' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,tes.name+'_to_load_MWh_t'] = tes2load
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:440: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.013309115622247174' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,tes.name+'_to_load_MWh_e'] = tes2load*tes.efficiency_rating_t2e
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:396: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.00580442464356816' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[i+1,pv.name+'_to_grid_MWh_e'] = min(pv_remaining,max(0,poi_remaining))
# c:\Users\tljohn\Desktop\RPB Micmaq\code\system_stm.py:850: RuntimeWarning: invalid value encountered in divide
#   hourly_RES_LMP = 100 * np.array(metrics['hourly_RES_to_load']) / np.array(load_series)

# %%
# ---------------------------
# 3. Process TEA Output for Thermocline

def calculate_net_tes_flow(timeseries, charge_col, discharge_col):
    return timeseries[charge_col].values - timeseries[discharge_col].values

charge_col = 'ASGARD_PV_to_ASGARD_TES_MWh_e'
discharge_col = 'ASGARD_TES_to_load_MWh_e'

# spring
single_day = '2033-03-20'  
next_day = '2033-03-22'
tea_day_spring = tea_timeseries.loc[single_day:next_day]
ambient_temp_spring = ambient_temps.loc[single_day:next_day].values + 273.15
single_day = '2023-03-20'  
next_day = '2023-03-22'
temperature_greenhouse_spring_C = T_greenhouse.loc[single_day:next_day].values
temperature_greenhouse_spring_K = temperature_greenhouse_spring_C + 273.15
net_TES_flow_MW_day_spring =  calculate_net_tes_flow(tea_day_spring, charge_col, discharge_col)

net_TES_flow_MW_day = net_TES_flow_MW_day_spring[13:17]
ambient_temp = ambient_temp_spring.flatten()[13:17]
temperature_greenhouse = temperature_greenhouse_spring_K[13:17]
print(len(net_TES_flow_MW_day),len(ambient_temp),len(temperature_greenhouse))
print((net_TES_flow_MW_day),(ambient_temp),(temperature_greenhouse))
# Out:
# 4 4 4
# [ 0.1         0.08943328  0.05573171 -0.00802903] [272.05 271.95 271.55 270.55] [313.15 303.15 303.15 303.15]

# %%
net_TES_flow_MW_day = [0.033,0.033,0.033,0.033,0.033,0.033,0,0,0,0,-0.033,-0.033,-0.033,-0.033,-0.033,-0.033]
# net_TES_flow_MW_day = [0.033, -0.1]
length = len(net_TES_flow_MW_day)
print(length)
ambient_temp = ambient_temp_spring.flatten()[13:13+length]
T_charge_K = 25 + 273.15
ambient_temp = np.full(length, T_charge_K)
temperature_greenhouse = temperature_greenhouse_spring_K[13:13+length]
print(len(net_TES_flow_MW_day),len(ambient_temp),len(temperature_greenhouse))
print((net_TES_flow_MW_day),(ambient_temp),(temperature_greenhouse))
# Out:
# 16
# 16 16 16
# [0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0, 0, 0, 0, -0.033, -0.033, -0.033, -0.033, -0.033, -0.033] [298.15 298.15 298.15 298.15 298.15 298.15 298.15 298.15 298.15 298.15
#  298.15 298.15 298.15 298.15 298.15 298.15] [313.15 303.15 303.15 303.15 303.15 303.15 303.15 303.15 303.15 303.15
#  303.15 303.15 303.15 303.15 303.15 303.15]

# %%
# Geo_study.ipynb
# ---------------------------
# 4. Geometry and Thermocline Initialization

### model inputs 
# Simulation geometry
rL = 0.2286
rR = 1.0019
B =  0.501
v = np.pi * (rR**2 - rL**2) * B
print(f'Ratio: {round(B/rR,3)}, Volume: {round(v,3)} m3')
n = 30 # 65 #*****************************************************************************
################

GEOM_type = 'Radial'
HTF_type = 'air'
alpha = 0.9       
Dp = 0.009525     
eps = 0.4         
alpha_gravel = 3.0E-7   
h_surf_upper = 1.66
h_surf_lower = 0.1
h_surf_outer = 2.0
h_surf_inner = 0.02

# Air properties
cp_air = 1005.0  

if GEOM_type[0] == 'A':
    A_avg = 1
elif GEOM_type[0] == 'R':
    A_left = 2 * np.pi * rL * B
    A_right = 2 * np.pi * rR * B
    A_avg = (A_left + A_right) / 2
elif GEOM_type[0] == 'S':
    A_left = 4 * np.pi * rL**2
    A_right = 4 * np.pi * rR**2
    A_avg = (A_left + A_right) / 2


# Get mass flow rates 
chargeTemp = 500+273.15  # K 
mass_flow_rates = []
for hr, power_MW in enumerate(net_TES_flow_MW_day):
    power_W = power_MW * 1e6  # Convert MW to W
    # Determine delta T based on charging or discharging
    if power_MW > 0:  # Charging logic
        deltaT = chargeTemp - ambient_temp[hr]
    else:  # Discharging logic
        deltaT = chargeTemp - temperature_greenhouse[hr]
     
    if abs(deltaT) < 1e-3:
        mdot = 0
    else:
        mdot = power_W / (cp_air * deltaT)  # Calculate mass flow rate
    
    mass_flow_rates.append(mdot)

mass_flow_rates = np.array(mass_flow_rates)
print(f'net_TES_flow_MW_day, mass_flow_rates: {net_TES_flow_MW_day, mass_flow_rates}')

# simulation history matrix for 24 hourly phases
simPhases = []
for hr in range(len(mass_flow_rates)):
    M_dot   = mass_flow_rates[hr]
    duration = 1     # hour

    if M_dot > 0:
        # charging: cold side is outside ambient
        inletTemp = chargeTemp
        T_ref     = ambient_temp[hr]
    elif M_dot < 0:
        # discharging: cold side is greenhouse
        inletTemp = temperature_greenhouse[hr]
        T_ref     = temperature_greenhouse[hr]
    else:
        # hold: just lock it in at outside ambient
        inletTemp = ambient_temp[hr]
        T_ref     = ambient_temp[hr]

    simPhases.append([M_dot, duration, inletTemp, T_ref])
simHist = np.array(simPhases)
simHist
# Out:
# Ratio: 0.5, Volume: 1.498 m3
# net_TES_flow_MW_day, mass_flow_rates: ([0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0, 0, 0, 0, -0.033, -0.033, -0.033, -0.033, -0.033, -0.033], array([ 0.06912804,  0.06912804,  0.06912804,  0.06912804,  0.06912804,
#         0.06912804,  0.        ,  0.        ,  0.        ,  0.        ,
#        -0.06986345, -0.06986345, -0.06986345, -0.06986345, -0.06986345,
#        -0.06986345]))
# array([[ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 6.91280440e-02,  1.00000000e+00,  7.73150000e+02,
#          2.98150000e+02],
#        [ 0.00000000e+00,  1.00000000e+00,  2.98150000e+02,
#          2.98150000e+02],
#        [ 0.00000000e+00,  1.00000000e+00,  2.98150000e+02,
#          2.98150000e+02],
#        [ 0.00000000e+00,  1.00000000e+00,  2.98150000e+02,
#          2.98150000e+02],
#        [ 0.00000000e+00,  1.00000000e+00,  2.98150000e+02,
#          2.98150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02],
#        [-6.98634487e-02,  1.00000000e+00,  3.03150000e+02,
#          3.03150000e+02]])

# %%
optimized_insul_thickness = estimate_min_insulation_thickness(rL, rR, B, simHist, ΔT_allow = 3)
print("optimized super-wool thickness:", optimized_insul_thickness)
# Out:
# optimized super-wool thickness: 0.2772853440309786

# %%
trace_radii = np.linspace(rL, rR, 1000)

# Color mapping
charge_colors = {1: 'r', 0: 'g', -1: 'b'}

# Initial conditions
initial_phase = simHist[0]
M_dot_initial = initial_phase[0]
duration_initial = initial_phase[1] * 3600  
T_g0 = initial_phase[2]
T_s0 = ambient_temp[0] 

T_ref = T_s0
Tavg = (T_g0 + T_s0) / 2

estThermoclineLength, estSuperficialVelocity, estThermoclineVelocity = estimate_thermocline(
    M_dot_initial, A_avg, eps, alpha, Dp, Tavg, HTF_type)

if estThermoclineLength <= 0 or not np.isfinite(estThermoclineLength):
    estThermoclineLength = 0.1
if estSuperficialVelocity <= 0 or not np.isfinite(estSuperficialVelocity):
    estSuperficialVelocity = 0.01

dr = estThermoclineLength / n 
if dr <= 0:
    dr = 1e-3
dr = 0.001326770622294117 # ******************************************************************

LengthDomain = rR - rL
NSegs = max(int(np.floor(LengthDomain / dr)), 1)
NPoints = NSegs + 1

dt = 0.07 * (dr / estSuperficialVelocity) # ******************************************************************

T_initial = float(T_s0)
Tg = np.full(NPoints, T_initial, dtype=np.float64)
Ts = np.full(NPoints, T_initial, dtype=np.float64)
Tg[0] = float(T_g0)
Ts[0] = float(T_g0)

r = np.linspace(rL, rR, NPoints, dtype=np.float64)

# Get trace indices
NodesToTraceInTime = [np.abs(r - radius).argmin() for radius in trace_radii]

total_pumping_kWh       = 0.0
global_peak_pump_kW     = 0.0
total_charge_ex_kWh     = 0.0
total_discharge_ex_kWh  = 0.0
total_energy_charged_kWh = 0.0
total_energy_discharged_kWh = 0.0
total_stored_energy = 0.0

# History storage
sim_data = []
sim_data_energy = []
timeHistory = np.zeros((1, 1 + 2 * len(NodesToTraceInTime)))
phase_change_times = []

phaseStartTime = 0
 
for iPhase, phase in enumerate(simHist):
    M_dot = phase[0]
    duration_sec = phase[1] * 3600
    T_g0 = phase[2]
    T_ref = phase[3]

    numSteps = int(np.floor(duration_sec / dt))
    if numSteps <= 0:
        continue

    charge_state = 1 if M_dot > 0 else 0 if M_dot == 0 else -1
    line_color = charge_colors[charge_state]
    
    Ts, Tg, timeHistory, phaseEndTime, energy_in, stored_energy_hist, pumping_kWh, dp_avg, peak_pump_kW, charge_exergy_hist, discharge_exergy_hist, energy_charge_hist, energy_discharge_hist, T_gas_inner  = radial_thermocline(
        Ts, Tg, HTF_type, r, numSteps, alpha, Dp, eps, B, alpha_gravel,
        h_surf_upper, h_surf_lower, h_surf_outer, h_surf_inner,
        M_dot, phaseStartTime, dt, T_g0, T_ref,
        NodesToTraceInTime, TraceTimeIncrement=5*60, timeHistory=timeHistory, MinUsefulTemp=35, optimized_insul_thickness = optimized_insul_thickness, rR = rR
    )

    total_charge_exergy_phase     = np.nansum(charge_exergy_hist)
    total_discharge_exergy_phase  = np.nansum(discharge_exergy_hist)
    total_energy_charged_phase    = np.nansum(energy_charge_hist)
    total_energy_discharged_phase = np.nansum(energy_discharge_hist)
    total_stored_energy_phase     = np.nansum(stored_energy_hist)

    total_charge_ex_kWh           += total_charge_exergy_phase
    total_discharge_ex_kWh        += total_discharge_exergy_phase
    total_energy_charged_kWh      += total_energy_charged_phase
    total_energy_discharged_kWh   += total_energy_discharged_phase
    total_stored_energy           += total_stored_energy_phase

    if not np.isnan(pumping_kWh):
        total_pumping_kWh += pumping_kWh
    if not np.isnan(peak_pump_kW):
        global_peak_pump_kW = max(global_peak_pump_kW, peak_pump_kW)

    print(f'total_pumping_kWh: {total_pumping_kWh}, global_peak_pump_kW: {global_peak_pump_kW}, total_charge_ex_kWh: {total_charge_ex_kWh}, total_discharge_ex_kWh: {total_discharge_ex_kWh}')
    
    df_phase = pd.DataFrame({
        'Phase': iPhase,
        'SimTime_sec': phaseEndTime,
        'Radius_m': r,
        'Temperature_C': Ts - 273.15,
        'Line_Color': line_color
    })

    T_gas_inner = np.array(T_gas_inner) - 273.15

    times = np.arange(numSteps)*dt + phaseStartTime
    df_energy_phase = pd.DataFrame({
        'Phase': iPhase,
        'SimTime_sec': times,
        'Gas Temp (C)' : T_gas_inner,
        'Stored_Energy_kWh': stored_energy_hist,
        'Charge_Exergy_kWh': charge_exergy_hist,
        'Discharge_Exergy_kWh': discharge_exergy_hist,
        'Energy_Charged_kWh': energy_charge_hist,
        'Energy_Discharged_kWh': energy_discharge_hist,
    })

    sim_data.append(df_phase)
    sim_data_energy.append(df_energy_phase)

    phaseStartTime = phaseEndTime
    phase_change_times.append(phaseEndTime)

sim_data = pd.concat(sim_data, ignore_index=True)
sim_data_energy = pd.concat(sim_data_energy, ignore_index=True)
timeHistory = timeHistory[:np.max(np.where(timeHistory[:, 0] > 0)[0]) + 1]
# Out:
# Mdot: 0.06912804399057344
# v_s: 0.09847733699122058
# Step 0, t=0.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.04 K @ r=0.230 m
# convective HT g>s : 0.0029450959347040685, th diffusion: 0.00016227213397973628, outer loss: 6.058206337365239e-14, inner loss: 0.0005352050703506579
# Step 0/3817199: t = 0.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 10.041, pumping_energy: 0.009, charging exergy: 35.46, discharging exergy: 0.00
# Step 100000, t=94.3s → CFL_max=0.62, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.242 m
# convective HT g>s : 0.0453724499481477, th diffusion: 4.033619638897659e-06, outer loss: 5.3331309451487256e-09, inner loss: 0.000611595596069553
# Step 100000/3817199: t = 94.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 11.728, pumping_energy: 1055.215, charging exergy: 35.46, discharging exergy: 0.00
# Step 200000, t=188.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.253 m
# convective HT g>s : 0.046405010457035455, th diffusion: 5.536443519454267e-07, outer loss: 8.794360995087902e-09, inner loss: 0.0005371072589687873
# Step 200000/3817199: t = 188.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 12.384, pumping_energy: 2192.388, charging exergy: 35.46, discharging exergy: 0.00
# Step 300000, t=282.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.259 m
# convective HT g>s : 0.045313029940599915, th diffusion: 1.3259162022744113e-07, outer loss: 1.0573927493359792e-08, inner loss: 0.0005343466776891468
# Step 300000/3817199: t = 282.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 13.027, pumping_energy: 3390.796, charging exergy: 35.46, discharging exergy: 0.00
# Step 400000, t=377.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.267 m
# convective HT g>s : 0.04422649934973039, th diffusion: -1.9762143784673642e-07, outer loss: 1.1186852382993572e-08, inner loss: 0.000534227124969259
# Step 400000/3817199: t = 377.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 13.644, pumping_energy: 4648.692, charging exergy: 35.46, discharging exergy: 0.00
# Step 500000, t=471.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.274 m
# convective HT g>s : 0.043202717139567595, th diffusion: -3.728789688626139e-07, outer loss: 1.1133994575352753e-08, inner loss: 0.0005343776260085114
# Step 500000/3817199: t = 471.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 14.235, pumping_energy: 5963.527, charging exergy: 35.46, discharging exergy: 0.00
# Step 600000, t=565.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.280 m
# convective HT g>s : 0.04224298553432885, th diffusion: -4.6511248409600835e-07, outer loss: 1.079316369961732e-08, inner loss: 0.0005345461679080257
# Step 600000/3817199: t = 565.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 14.800, pumping_energy: 7332.849, charging exergy: 35.46, discharging exergy: 0.00
# Step 700000, t=660.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.286 m
# convective HT g>s : 0.041342945999814584, th diffusion: -5.135782023692962e-07, outer loss: 1.0403612466490942e-08, inner loss: 0.0005346777287453696
# Step 700000/3817199: t = 660.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 15.342, pumping_energy: 8754.382, charging exergy: 35.46, discharging exergy: 0.00
# Step 800000, t=754.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.292 m
# convective HT g>s : 0.040497155614858955, th diffusion: -5.380390309459269e-07, outer loss: 1.0090118071566298e-08, inner loss: 0.0005347711324460581
# Step 800000/3817199: t = 754.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 15.863, pumping_energy: 10226.012, charging exergy: 35.46, discharging exergy: 0.00
# Step 900000, t=848.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.299 m
# convective HT g>s : 0.039700489474411245, th diffusion: -5.489310777795834e-07, outer loss: 9.898377801219264e-09, inner loss: 0.0005348352906451768
# Step 900000/3817199: t = 848.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 16.363, pumping_energy: 11745.768, charging exergy: 35.46, discharging exergy: 0.00
# Step 1000000, t=943.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.304 m
# convective HT g>s : 0.03894840562152141, th diffusion: -5.519976148391919e-07, outer loss: 9.827714124883415e-09, inner loss: 0.0005348788452398145
# Step 1000000/3817199: t = 943.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 16.844, pumping_energy: 13311.809, charging exergy: 35.46, discharging exergy: 0.00
# Step 1100000, t=1037.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.311 m
# convective HT g>s : 0.03823692777283819, th diffusion: -5.5050575402384e-07, outer loss: 9.855709637289036e-09, inner loss: 0.0005349083278376367
# Step 1100000/3817199: t = 1037.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 17.308, pumping_energy: 14922.410, charging exergy: 35.46, discharging exergy: 0.00
# Step 1200000, t=1131.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.316 m
# convective HT g>s : 0.03756257080441523, th diffusion: -5.463632472296662e-07, outer loss: 9.953997115514224e-09, inner loss: 0.0005349283089989329
# Step 1200000/3817199: t = 1131.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 17.755, pumping_energy: 16575.956, charging exergy: 35.46, discharging exergy: 0.00
# Step 1300000, t=1226.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.322 m
# convective HT g>s : 0.036922265044120356, th diffusion: -5.40706725907964e-07, outer loss: 1.009681846271027e-08, inner loss: 0.0005349418936668784
# Step 1300000/3817199: t = 1226.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 18.187, pumping_energy: 18270.930, charging exergy: 35.46, discharging exergy: 0.00
# Step 1400000, t=1320.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.327 m
# convective HT g>s : 0.03631329162655629, th diffusion: -5.342234551301283e-07, outer loss: 1.0264483482694864e-08, inner loss: 0.0005349511674035124
# Step 1400000/3817199: t = 1320.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 18.604, pumping_energy: 20005.907, charging exergy: 35.46, discharging exergy: 0.00
# Step 1500000, t=1414.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.332 m
# convective HT g>s : 0.035733229679212886, th diffusion: -5.273329912499796e-07, outer loss: 1.0443793659989667e-08, inner loss: 0.0005349575267747965
# Step 1500000/3817199: t = 1414.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 19.007, pumping_energy: 21779.544, charging exergy: 35.46, discharging exergy: 0.00
# Step 1600000, t=1509.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.338 m
# convective HT g>s : 0.03517991347469034, th diffusion: -5.202925078554023e-07, outer loss: 1.062704496757297e-08, inner loss: 0.0005349619078720764
# Step 1600000/3817199: t = 1509.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 19.397, pumping_energy: 23590.579, charging exergy: 35.46, discharging exergy: 0.00
# Step 1700000, t=1603.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.343 m
# convective HT g>s : 0.03465139746511772, th diffusion: -5.132592437674326e-07, outer loss: 1.0810411466113085e-08, inner loss: 0.0005349649400311509
# Step 1700000/3817199: t = 1603.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 19.775, pumping_energy: 25437.819, charging exergy: 35.46, discharging exergy: 0.00
# Step 1800000, t=1697.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.348 m
# convective HT g>s : 0.03414592745450259, th diffusion: -5.063282262724119e-07, outer loss: 1.0992552152125232e-08, inner loss: 0.000534967048068288
# Step 1800000/3817199: t = 1697.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 20.141, pumping_energy: 27320.139, charging exergy: 35.46, discharging exergy: 0.00
# Step 1900000, t=1791.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.353 m
# convective HT g>s : 0.03366191657662707, th diffusion: -4.995554314029017e-07, outer loss: 1.1173421607410219e-08, inner loss: 0.0005349685200454067
# Step 1900000/3817199: t = 1791.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 20.496, pumping_energy: 29236.474, charging exergy: 35.46, discharging exergy: 0.00
# Step 2000000, t=1886.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.359 m
# convective HT g>s : 0.033197925071036034, th diffusion: -4.929721866122278e-07, outer loss: 1.1353537931258795e-08, inner loss: 0.0005349695522164792
# Step 2000000/3817199: t = 1886.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 20.841, pumping_energy: 31185.818, charging exergy: 35.46, discharging exergy: 0.00
# Step 2100000, t=1980.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.364 m
# convective HT g>s : 0.03275264310533426, th diffusion: -4.865942365314113e-07, outer loss: 1.1533517590954313e-08, inner loss: 0.0005349702789235126
# Step 2100000/3817199: t = 1980.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 21.176, pumping_energy: 33167.217, charging exergy: 35.46, discharging exergy: 0.00
# Step 2200000, t=2074.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.368 m
# convective HT g>s : 0.03232487607135979, th diffusion: -4.804274990368647e-07, outer loss: 1.1713853563032347e-08, inner loss: 0.0005349707925600965
# Step 2200000/3817199: t = 2074.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 21.502, pumping_energy: 35179.767, charging exergy: 35.46, discharging exergy: 0.00
# Step 2300000, t=2169.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.373 m
# convective HT g>s : 0.03191353191533683, th diffusion: -4.744717483585617e-07, outer loss: 1.189487728567143e-08, inner loss: 0.0005349711569443029
# Step 2300000/3817199: t = 2169.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 21.819, pumping_energy: 37222.607, charging exergy: 35.46, discharging exergy: 0.00
# Step 2400000, t=2263.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.377 m
# convective HT g>s : 0.0315176101578142, th diffusion: -4.687229856566332e-07, outer loss: 1.2076713914611326e-08, inner loss: 0.000534971416386824
# Step 2400000/3817199: t = 2263.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 22.127, pumping_energy: 39294.923, charging exergy: 35.46, discharging exergy: 0.00
# Step 2500000, t=2357.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.383 m
# convective HT g>s : 0.03113619233315009, th diffusion: -4.631749695595938e-07, outer loss: 1.2259402991009947e-08, inner loss: 0.0005349716017315799
# Step 2500000/3817199: t = 2357.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 22.427, pumping_energy: 41395.936, charging exergy: 35.46, discharging exergy: 0.00
# Step 2600000, t=2452.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.388 m
# convective HT g>s : 0.030768433625869715, th diffusion: -4.578202055711062e-07, outer loss: 1.24428555738879e-08, inner loss: 0.0005349717345868616
# Step 2600000/3817199: t = 2452.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 22.720, pumping_energy: 43524.908, charging exergy: 35.46, discharging exergy: 0.00
# Step 2700000, t=2546.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.392 m
# convective HT g>s : 0.03041355552726342, th diffusion: -4.5265058359262837e-07, outer loss: 1.262699494130109e-08, inner loss: 0.0005349718301462226
# Step 2700000/3817199: t = 2546.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 23.005, pumping_energy: 45681.133, charging exergy: 35.46, discharging exergy: 0.00
# Step 2800000, t=2640.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.396 m
# convective HT g>s : 0.03007083937082768, th diffusion: -4.476577950679712e-07, outer loss: 1.2811685261080106e-08, inner loss: 0.0005349718990567424
# Step 2800000/3817199: t = 2640.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 23.284, pumping_energy: 47863.938, charging exergy: 35.46, discharging exergy: 0.00
# Step 2900000, t=2735.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.401 m
# convective HT g>s : 0.0297396206076552, th diffusion: -4.428335710579949e-07, outer loss: 1.2996842586773195e-08, inner loss: 0.0005349719489274608
# Step 2900000/3817199: t = 2735.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 23.555, pumping_energy: 50072.681, charging exergy: 35.46, discharging exergy: 0.00
# Step 3000000, t=2829.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.405 m
# convective HT g>s : 0.0294192837470239, th diffusion: -4.381698679180399e-07, outer loss: 1.3182360895062282e-08, inner loss: 0.0005349719850702247
# Step 3000000/3817199: t = 2829.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 23.821, pumping_energy: 52306.746, charging exergy: 35.46, discharging exergy: 0.00
# Step 3100000, t=2923.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.409 m
# convective HT g>s : 0.0291092578424949, th diffusion: -4.3365892652973324e-07, outer loss: 1.3368179644295181e-08, inner loss: 0.0005349720113778672
# Step 3100000/3817199: t = 2923.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 24.080, pumping_energy: 54565.547, charging exergy: 35.46, discharging exergy: 0.00
# Step 3200000, t=3017.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.415 m
# convective HT g>s : 0.028809012487428915, th diffusion: -4.2929335561543185e-07, outer loss: 1.3554233279015093e-08, inner loss: 0.0005349720305860852
# Step 3200000/3817199: t = 3017.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 24.333, pumping_energy: 56848.520, charging exergy: 35.46, discharging exergy: 0.00
# Step 3300000, t=3112.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.419 m
# convective HT g>s : 0.02851805422918922, th diffusion: -4.2506614525388375e-07, outer loss: 1.3740480724168309e-08, inner loss: 0.0005349720446349773
# Step 3300000/3817199: t = 3112.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 24.581, pumping_energy: 59155.126, charging exergy: 35.46, discharging exergy: 0.00
# Step 3400000, t=3206.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.423 m
# convective HT g>s : 0.028235923359800134, th diffusion: -4.2097066208927956e-07, outer loss: 1.3926887650999108e-08, inner loss: 0.0005349720549105984
# Step 3400000/3817199: t = 3206.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 24.824, pumping_energy: 61484.849, charging exergy: 35.46, discharging exergy: 0.00
# Step 3500000, t=3300.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.427 m
# convective HT g>s : 0.027962191036861296, th diffusion: -4.1700064794995794e-07, outer loss: 1.4113418815384039e-08, inner loss: 0.0005349720624838567
# Step 3500000/3817199: t = 3300.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.061, pumping_energy: 63837.190, charging exergy: 35.46, discharging exergy: 0.00
# Step 3600000, t=3395.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.432 m
# convective HT g>s : 0.027696456702246033, th diffusion: -4.1315021512270405e-07, outer loss: 1.430006414398713e-08, inner loss: 0.0005349720680821535
# Step 3600000/3817199: t = 3395.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.293, pumping_energy: 66211.674, charging exergy: 35.46, discharging exergy: 0.00
# Step 3700000, t=3489.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.436 m
# convective HT g>s : 0.027438345752241272, th diffusion: -4.094138271566069e-07, outer loss: 1.4486785604185207e-08, inner loss: 0.0005349720722104382
# Step 3700000/3817199: t = 3489.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.521, pumping_energy: 68607.841, charging exergy: 35.46, discharging exergy: 0.00
# Step 3800000, t=3583.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.440 m
# convective HT g>s : 0.027187507433877954, th diffusion: -4.05786268976694e-07, outer loss: 1.4673588822739186e-08, inner loss: 0.0005349720752600825
# Step 3800000/3817199: t = 3583.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.744, pumping_energy: 71025.252, charging exergy: 35.46, discharging exergy: 0.00
# c:\Users\tljohn\Desktop\RPB Micmaq\code\radial_thermocline.py:302: RuntimeWarning: divide by zero encountered in scalar divide
#   dp_avg          = dp_time_integral / sim_time_total
# total_pumping_kWh: 0.01984530784875153, global_peak_pump_kW: 0.02578161748955566, total_charge_ex_kWh: 37.59587678941032, total_discharge_ex_kWh: 0.0
# Step 0, t=3600.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.440 m
# convective HT g>s : 0.027145074419195107, th diffusion: -4.0517297147767645e-07, outer loss: 1.4705720718821236e-08, inner loss: 0.0005349720757008149
# Step 0/3817199: t = 3600.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.782, pumping_energy: 0.024, charging exergy: 35.46, discharging exergy: 0.00
# Step 100000, t=3694.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.444 m
# convective HT g>s : 0.026902342565935794, th diffusion: -4.016667413189297e-07, outer loss: 1.4892575590104147e-08, inner loss: 0.0005349720778752054
# Step 100000/3817199: t = 3694.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 25.999, pumping_energy: 2441.793, charging exergy: 35.46, discharging exergy: 0.00
# Step 200000, t=3788.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.448 m
# convective HT g>s : 0.026666194836953695, th diffusion: -3.9825906665451e-07, outer loss: 1.507947694673608e-08, inner loss: 0.0005349720794730662
# Step 200000/3817199: t = 3788.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 26.213, pumping_energy: 4903.902, charging exergy: 35.46, discharging exergy: 0.00
# Step 300000, t=3882.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.452 m
# convective HT g>s : 0.02643634440970269, th diffusion: -3.9494564506567836e-07, outer loss: 1.526639730655077e-08, inner loss: 0.0005349720806677789
# Step 300000/3817199: t = 3882.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 26.423, pumping_energy: 7385.962, charging exergy: 35.46, discharging exergy: 0.00
# Step 400000, t=3977.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.456 m
# convective HT g>s : 0.026212521493022032, th diffusion: -3.91722433499636e-07, outer loss: 1.5453340923289555e-08, inner loss: 0.0005349720815656235
# Step 400000/3817199: t = 3977.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 26.628, pumping_energy: 9887.593, charging exergy: 35.46, discharging exergy: 0.00
# Step 500000, t=4071.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.460 m
# convective HT g>s : 0.025994472059754616, th diffusion: -3.88585620846457e-07, outer loss: 1.5640283408963512e-08, inner loss: 0.0005349720822158055
# Step 500000/3817199: t = 4071.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 26.830, pumping_energy: 12408.432, charging exergy: 35.46, discharging exergy: 0.00
# Step 600000, t=4165.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.464 m
# convective HT g>s : 0.025781956688169447, th diffusion: -3.8553160668699665e-07, outer loss: 1.5827229800432758e-08, inner loss: 0.0005349720827135579
# Step 600000/3817199: t = 4165.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.028, pumping_energy: 14948.127, charging exergy: 35.46, discharging exergy: 0.00
# Step 700000, t=4260.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.468 m
# convective HT g>s : 0.02557474951316357, th diffusion: -3.8255700193744416e-07, outer loss: 1.6014160992686038e-08, inner loss: 0.0005349720830749813
# Step 700000/3817199: t = 4260.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.223, pumping_energy: 17506.338, charging exergy: 35.46, discharging exergy: 0.00
# Step 800000, t=4354.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.472 m
# convective HT g>s : 0.025372637258302966, th diffusion: -3.7965859703070806e-07, outer loss: 1.620107917894265e-08, inner loss: 0.0005349720833512584
# Step 800000/3817199: t = 4354.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.414, pumping_energy: 20082.736, charging exergy: 35.46, discharging exergy: 0.00
# Step 900000, t=4448.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.476 m
# convective HT g>s : 0.02517541835692205, th diffusion: -3.76833362075343e-07, outer loss: 1.6387974774579373e-08, inner loss: 0.0005349720835780573
# Step 900000/3817199: t = 4448.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.602, pumping_energy: 22677.004, charging exergy: 35.46, discharging exergy: 0.00
# Step 1000000, t=4543.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.480 m
# convective HT g>s : 0.0249829021454051, th diffusion: -3.7407843539502823e-07, outer loss: 1.6574841844852102e-08, inner loss: 0.000534972083748803
# Step 1000000/3817199: t = 4543.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.786, pumping_energy: 25288.834, charging exergy: 35.46, discharging exergy: 0.00
# Step 1100000, t=4637.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.482 m
# convective HT g>s : 0.02479490811873436, th diffusion: -3.713911014204801e-07, outer loss: 1.6761679088085257e-08, inner loss: 0.0005349720838788533
# Step 1100000/3817199: t = 4637.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 27.968, pumping_energy: 27917.929, charging exergy: 35.46, discharging exergy: 0.00
# Step 1200000, t=4731.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.486 m
# convective HT g>s : 0.024611265251764745, th diffusion: -3.6876879093814774e-07, outer loss: 1.694847559389982e-08, inner loss: 0.000534972083981453
# Step 1200000/3817199: t = 4731.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.146, pumping_energy: 30563.999, charging exergy: 35.46, discharging exergy: 0.00
# Step 1300000, t=4826.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.490 m
# convective HT g>s : 0.024431811371995828, th diffusion: -3.662090669353091e-07, outer loss: 1.713523698374113e-08, inner loss: 0.0005349720840586842
# Step 1300000/3817199: t = 4826.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.322, pumping_energy: 33226.767, charging exergy: 35.46, discharging exergy: 0.00
# Step 1400000, t=4920.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.494 m
# convective HT g>s : 0.024256392583407126, th diffusion: -3.637096178713839e-07, outer loss: 1.7321949078151175e-08, inner loss: 0.0005349720841148643
# Step 1400000/3817199: t = 4920.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.495, pumping_energy: 35905.960, charging exergy: 35.46, discharging exergy: 0.00
# Step 1500000, t=5014.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.498 m
# convective HT g>s : 0.024084862733407392, th diffusion: -3.612682474538291e-07, outer loss: 1.750862106782421e-08, inner loss: 0.0005349720841549784
# Step 1500000/3817199: t = 5014.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.665, pumping_energy: 38601.316, charging exergy: 35.46, discharging exergy: 0.00
# Step 1600000, t=5109.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.501 m
# convective HT g>s : 0.02391708292352414, th diffusion: -3.588828704995672e-07, outer loss: 1.7695237424106664e-08, inner loss: 0.0005349720841783546
# Step 1600000/3817199: t = 5109.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.832, pumping_energy: 41312.581, charging exergy: 35.46, discharging exergy: 0.00
# Step 1700000, t=5203.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.505 m
# convective HT g>s : 0.023752921053697963, th diffusion: -3.565515016409512e-07, outer loss: 1.7881807754933452e-08, inner loss: 0.000534972084197337
# Step 1700000/3817199: t = 5203.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 28.997, pumping_energy: 44039.506, charging exergy: 35.46, discharging exergy: 0.00
# Step 1800000, t=5297.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.509 m
# convective HT g>s : 0.023592251405389036, th diffusion: -3.542722570930296e-07, outer loss: 1.8068318412468162e-08, inner loss: 0.0005349720842068076
# Step 1800000/3817199: t = 5297.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.159, pumping_energy: 46781.852, charging exergy: 35.46, discharging exergy: 0.00
# Step 1900000, t=5391.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.512 m
# convective HT g>s : 0.02343495424961142, th diffusion: -3.5204333472915703e-07, outer loss: 1.8254777556439553e-08, inner loss: 0.000534972084222578
# Step 1900000/3817199: t = 5391.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.319, pumping_energy: 49539.384, charging exergy: 35.46, discharging exergy: 0.00
# Step 2000000, t=5486.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.516 m
# convective HT g>s : 0.023280915490711897, th diffusion: -3.498630269009653e-07, outer loss: 1.84411764762203e-08, inner loss: 0.0005349720842270212
# Step 2000000/3817199: t = 5486.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.476, pumping_energy: 52311.876, charging exergy: 35.46, discharging exergy: 0.00
# Step 2100000, t=5580.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.518 m
# convective HT g>s : 0.023130026328587835, th diffusion: -3.477296995964366e-07, outer loss: 1.8627518138670098e-08, inner loss: 0.0005349720842270212
# Step 2100000/3817199: t = 5580.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.631, pumping_energy: 55099.107, charging exergy: 35.46, discharging exergy: 0.00
# Step 2200000, t=5674.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.522 m
# convective HT g>s : 0.022982182949714318, th diffusion: -3.4564179452263835e-07, outer loss: 1.881379795785616e-08, inner loss: 0.0005349720842359081
# Step 2200000/3817199: t = 5674.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.784, pumping_energy: 57900.863, charging exergy: 35.46, discharging exergy: 0.00
# Step 2300000, t=5769.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.526 m
# convective HT g>s : 0.022837286239843536, th diffusion: -3.4359782891382487e-07, outer loss: 1.9000015270292183e-08, inner loss: 0.0005349720842289804
# Step 2300000/3817199: t = 5769.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 29.935, pumping_energy: 60716.935, charging exergy: 35.46, discharging exergy: 0.00
# Step 2400000, t=5863.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.529 m
# convective HT g>s : 0.02269524151189224, th diffusion: -3.415963786772144e-07, outer loss: 1.9186170994291877e-08, inner loss: 0.0005349720842429514
# Step 2400000/3817199: t = 5863.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.083, pumping_energy: 63547.118, charging exergy: 35.46, discharging exergy: 0.00
# Step 2500000, t=5957.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.533 m
# convective HT g>s : 0.022555958261076533, th diffusion: -3.3963609054333076e-07, outer loss: 1.9372260877907116e-08, inner loss: 0.0005349720842373443
# Step 2500000/3817199: t = 5957.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.230, pumping_energy: 66391.217, charging exergy: 35.46, discharging exergy: 0.00
# Step 2600000, t=6052.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.536 m
# convective HT g>s : 0.022419349926573285, th diffusion: -3.3771566816258066e-07, outer loss: 1.9558288136484746e-08, inner loss: 0.0005349720842365195
# Step 2600000/3817199: t = 6052.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.375, pumping_energy: 69249.037, charging exergy: 35.46, discharging exergy: 0.00
# Step 2700000, t=6146.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.540 m
# convective HT g>s : 0.022285333677228385, th diffusion: -3.358338664829155e-07, outer loss: 1.9744246551121537e-08, inner loss: 0.0005349720842357951
# Step 2700000/3817199: t = 6146.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.517, pumping_energy: 72120.392, charging exergy: 35.46, discharging exergy: 0.00
# Step 2800000, t=6240.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.542 m
# convective HT g>s : 0.022153830207565554, th diffusion: -3.339895017244009e-07, outer loss: 1.9930140628721116e-08, inner loss: 0.0005349720842268417
# Step 2800000/3817199: t = 6240.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.658, pumping_energy: 75005.097, charging exergy: 35.46, discharging exergy: 0.00
# Step 2900000, t=6335.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.546 m
# convective HT g>s : 0.02202476354741192, th diffusion: -3.3218143163309165e-07, outer loss: 2.011596436703799e-08, inner loss: 0.0005349720842270213
# Step 2900000/3817199: t = 6335.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.796, pumping_energy: 77902.974, charging exergy: 35.46, discharging exergy: 0.00
# Step 3000000, t=6429.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.549 m
# convective HT g>s : 0.0218980608852854, th diffusion: -3.304085671607548e-07, outer loss: 2.0301722379671566e-08, inner loss: 0.000534972084238267
# Step 3000000/3817199: t = 6429.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 30.933, pumping_energy: 80813.850, charging exergy: 35.46, discharging exergy: 0.00
# Step 3100000, t=6523.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.553 m
# convective HT g>s : 0.021773652402384897, th diffusion: -3.286698647990772e-07, outer loss: 2.048741050567892e-08, inner loss: 0.0005349720842625683
# Step 3100000/3817199: t = 6523.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.068, pumping_energy: 83737.555, charging exergy: 35.46, discharging exergy: 0.00
# Step 3200000, t=6617.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.555 m
# convective HT g>s : 0.0216514711170239, th diffusion: -3.269643212344633e-07, outer loss: 2.0673030694851612e-08, inner loss: 0.0005349720842696168
# Step 3200000/3817199: t = 6617.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.202, pumping_energy: 86673.923, charging exergy: 35.46, discharging exergy: 0.00
# Step 3300000, t=6712.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.559 m
# convective HT g>s : 0.021531452737399433, th diffusion: -3.252909753581985e-07, outer loss: 2.0858580567540937e-08, inner loss: 0.0005349720842758984
# Step 3300000/3817199: t = 6712.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.334, pumping_energy: 89622.792, charging exergy: 35.46, discharging exergy: 0.00
# Step 3400000, t=6806.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.562 m
# convective HT g>s : 0.021413535525144384, th diffusion: -3.236489008384447e-07, outer loss: 2.1044061563947663e-08, inner loss: 0.000534972084294071
# Step 3400000/3817199: t = 6806.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.464, pumping_energy: 92584.005, charging exergy: 35.46, discharging exergy: 0.00
# Step 3500000, t=6900.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.565 m
# convective HT g>s : 0.021297660169515727, th diffusion: -3.220372140907526e-07, outer loss: 2.122947071413803e-08, inner loss: 0.0005349720842847851
# Step 3500000/3817199: t = 6900.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.592, pumping_energy: 95557.407, charging exergy: 35.46, discharging exergy: 0.00
# Step 3600000, t=6995.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.569 m
# convective HT g>s : 0.021183769661777246, th diffusion: -3.204550581518791e-07, outer loss: 2.1414810740647382e-08, inner loss: 0.0005349720842847851
# Step 3600000/3817199: t = 6995.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.719, pumping_energy: 98542.847, charging exergy: 35.46, discharging exergy: 0.00
# Step 3700000, t=7089.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.571 m
# convective HT g>s : 0.021071809186088312, th diffusion: -3.189016157566336e-07, outer loss: 2.160007843209954e-08, inner loss: 0.0005349720842847852
# Step 3700000/3817199: t = 7089.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.844, pumping_energy: 101540.180, charging exergy: 35.46, discharging exergy: 0.00
# Step 3800000, t=7183.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.575 m
# convective HT g>s : 0.02096172601110187, th diffusion: -3.173760962792704e-07, outer loss: 2.1785275344485174e-08, inner loss: 0.0005349720842847852
# Step 3800000/3817199: t = 7183.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.968, pumping_energy: 104549.259, charging exergy: 35.46, discharging exergy: 0.00
# total_pumping_kWh: 0.049030845227660075, global_peak_pump_kW: 0.03198920251502083, total_charge_ex_kWh: 75.19175357882064, total_discharge_ex_kWh: 0.0
# Step 0, t=7200.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.575 m
# convective HT g>s : 0.02094297827808132, th diffusion: -3.171164808839351e-07, outer loss: 2.1817121982508394e-08, inner loss: 0.0005349720842847852
# Step 0/3817199: t = 7200.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 31.989, pumping_energy: 0.030, charging exergy: 35.46, discharging exergy: 0.00
# Step 100000, t=7294.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.578 m
# convective HT g>s : 0.020835030830010846, th diffusion: -3.156227258322852e-07, outer loss: 2.2002231380410184e-08, inner loss: 0.0005349720842847852
# Step 100000/3817199: t = 7294.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.111, pumping_energy: 3022.699, charging exergy: 35.46, discharging exergy: 0.00
# Step 200000, t=7388.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.582 m
# convective HT g>s : 0.02072885285807304, th diffusion: -3.14155281411192e-07, outer loss: 2.218727539455467e-08, inner loss: 0.0005349720842847852
# Step 200000/3817199: t = 7388.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.232, pumping_energy: 6056.815, charging exergy: 35.46, discharging exergy: 0.00
# Step 300000, t=7482.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.585 m
# convective HT g>s : 0.020624397606065697, th diffusion: -3.1271345151664115e-07, outer loss: 2.2372241633374495e-08, inner loss: 0.0005349720842847852
# Step 300000/3817199: t = 7482.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.351, pumping_energy: 9102.243, charging exergy: 35.46, discharging exergy: 0.00
# Step 400000, t=7577.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.587 m
# convective HT g>s : 0.020521620019622742, th diffusion: -3.1129656023766945e-07, outer loss: 2.2557141586390245e-08, inner loss: 0.0005349720842847852
# Step 400000/3817199: t = 7577.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.469, pumping_energy: 12158.852, charging exergy: 35.46, discharging exergy: 0.00
# Step 500000, t=7671.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.591 m
# convective HT g>s : 0.02042047666838718, th diffusion: -3.099039605310156e-07, outer loss: 2.2741965372331148e-08, inner loss: 0.0005349720842847852
# Step 500000/3817199: t = 7671.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.586, pumping_energy: 15226.514, charging exergy: 35.46, discharging exergy: 0.00
# Step 600000, t=7765.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.594 m
# convective HT g>s : 0.020320925671196567, th diffusion: -3.0853502527072014e-07, outer loss: 2.292672003920214e-08, inner loss: 0.0005349720842847852
# Step 600000/3817199: t = 7765.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.701, pumping_energy: 18305.104, charging exergy: 35.46, discharging exergy: 0.00
# Step 700000, t=7860.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.597 m
# convective HT g>s : 0.020222926626416143, th diffusion: -3.0718915177383133e-07, outer loss: 2.311140100299172e-08, inner loss: 0.0005349720842847852
# Step 700000/3817199: t = 7860.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.815, pumping_energy: 21394.498, charging exergy: 35.46, discharging exergy: 0.00
# Step 800000, t=7954.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.599 m
# convective HT g>s : 0.02012644054534216, th diffusion: -3.0586575768516425e-07, outer loss: 2.329600980502468e-08, inner loss: 0.0005349720842847852
# Step 800000/3817199: t = 7954.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 32.927, pumping_energy: 24494.576, charging exergy: 35.46, discharging exergy: 0.00
# Step 900000, t=8048.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.603 m
# convective HT g>s : 0.020031429789595236, th diffusion: -3.04564280098315e-07, outer loss: 2.348055021910353e-08, inner loss: 0.0005349720842847852
# Step 900000/3817199: t = 8048.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.039, pumping_energy: 27605.221, charging exergy: 35.46, discharging exergy: 0.00
# Step 1000000, t=8143.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.606 m
# convective HT g>s : 0.019937858012034432, th diffusion: -3.0328417754738404e-07, outer loss: 2.3665015907589164e-08, inner loss: 0.0005349720842847852
# Step 1000000/3817199: t = 8143.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.149, pumping_energy: 30726.317, charging exergy: 35.46, discharging exergy: 0.00
# Step 1100000, t=8237.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.609 m
# convective HT g>s : 0.019845690099870944, th diffusion: -3.020249241513035e-07, outer loss: 2.3849417573296973e-08, inner loss: 0.0005349720842847852
# Step 1100000/3817199: t = 8237.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.258, pumping_energy: 33857.750, charging exergy: 35.46, discharging exergy: 0.00
# Step 1200000, t=8331.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.611 m
# convective HT g>s : 0.01975489212236676, th diffusion: -3.0078601597446194e-07, outer loss: 2.4033744135301228e-08, inner loss: 0.0005349720842847852
# Step 1200000/3817199: t = 8331.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.366, pumping_energy: 36999.410, charging exergy: 35.46, discharging exergy: 0.00
# Step 1300000, t=8426.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.615 m
# convective HT g>s : 0.019665431279375402, th diffusion: -2.9956696092016054e-07, outer loss: 2.4218012222451554e-08, inner loss: 0.0005349720842847852
# Step 1300000/3817199: t = 8426.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.473, pumping_energy: 40151.189, charging exergy: 35.46, discharging exergy: 0.00
# Step 1400000, t=8520.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.618 m
# convective HT g>s : 0.0195772758543258, th diffusion: -2.9836728871358344e-07, outer loss: 2.4402211974995647e-08, inner loss: 0.0005349720842847852
# Step 1400000/3817199: t = 8520.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.578, pumping_energy: 43312.979, charging exergy: 35.46, discharging exergy: 0.00
# Step 1500000, t=8614.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.621 m
# convective HT g>s : 0.019490395168015064, th diffusion: -2.971865391961101e-07, outer loss: 2.4586360880921053e-08, inner loss: 0.0005349720842847852
# Step 1500000/3817199: t = 8614.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.683, pumping_energy: 46484.676, charging exergy: 35.46, discharging exergy: 0.00
# Step 1600000, t=8709.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.623 m
# convective HT g>s : 0.019404759536265474, th diffusion: -2.960242728859522e-07, outer loss: 2.4770454655873836e-08, inner loss: 0.0005349720842847852
# Step 1600000/3817199: t = 8709.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.786, pumping_energy: 49666.178, charging exergy: 35.46, discharging exergy: 0.00
# Step 1700000, t=8803.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.626 m
# convective HT g>s : 0.01932034022816649, th diffusion: -2.9488006019551586e-07, outer loss: 2.495451168636594e-08, inner loss: 0.0005349720842847852
# Step 1700000/3817199: t = 8803.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.889, pumping_energy: 52857.384, charging exergy: 35.46, discharging exergy: 0.00
# Step 1800000, t=8897.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.629 m
# convective HT g>s : 0.019237109427774925, th diffusion: -2.9375348951705654e-07, outer loss: 2.5138537823245025e-08, inner loss: 0.0005349720842847852
# Step 1800000/3817199: t = 8897.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 33.990, pumping_energy: 56058.196, charging exergy: 35.46, discharging exergy: 0.00
# Step 1900000, t=8991.9s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.633 m
# convective HT g>s : 0.01915504019661029, th diffusion: -2.9264415951973815e-07, outer loss: 2.532255800187621e-08, inner loss: 0.0005349720842847852
# Step 1900000/3817199: t = 8991.9s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.090, pumping_energy: 59268.517, charging exergy: 35.46, discharging exergy: 0.00
# Step 2000000, t=9086.2s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.635 m
# convective HT g>s : 0.019074106438815693, th diffusion: -2.915516852693852e-07, outer loss: 2.550659173522517e-08, inner loss: 0.0005349720842847852
# Step 2000000/3817199: t = 9086.2s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.189, pumping_energy: 62488.252, charging exergy: 35.46, discharging exergy: 0.00
# Step 2100000, t=9180.5s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.638 m
# convective HT g>s : 0.018994282867254228, th diffusion: -2.9047569343017107e-07, outer loss: 2.5690672970478946e-08, inner loss: 0.0005349720842847852
# Step 2100000/3817199: t = 9180.5s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.288, pumping_energy: 65717.307, charging exergy: 35.46, discharging exergy: 0.00
# Step 2200000, t=9274.8s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.640 m
# convective HT g>s : 0.018915544971852494, th diffusion: -2.894158240206415e-07, outer loss: 2.587484735914567e-08, inner loss: 0.0005349720842847852
# Step 2200000/3817199: t = 9274.8s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.385, pumping_energy: 68955.592, charging exergy: 35.46, discharging exergy: 0.00
# Step 2300000, t=9369.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.643 m
# convective HT g>s : 0.018837868989082716, th diffusion: -2.883717310631178e-07, outer loss: 2.6059167450173135e-08, inner loss: 0.0005349720842847852
# Step 2300000/3817199: t = 9369.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.482, pumping_energy: 72203.016, charging exergy: 35.46, discharging exergy: 0.00
# Step 2400000, t=9463.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.646 m
# convective HT g>s : 0.01876123187274872, th diffusion: -2.8734307926655616e-07, outer loss: 2.624371544272575e-08, inner loss: 0.0005349720842847852
# Step 2400000/3817199: t = 9463.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.577, pumping_energy: 75459.491, charging exergy: 35.46, discharging exergy: 0.00
# Step 2500000, t=9557.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.648 m
# convective HT g>s : 0.018685611266719297, th diffusion: -2.863295511591818e-07, outer loss: 2.6428578082322106e-08, inner loss: 0.0005349720842847852
# Step 2500000/3817199: t = 9557.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.672, pumping_energy: 78724.930, charging exergy: 35.46, discharging exergy: 0.00
# Step 2600000, t=9652.1s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.651 m
# convective HT g>s : 0.0186109854779028, th diffusion: -2.8533083800106265e-07, outer loss: 2.66138912590906e-08, inner loss: 0.0005349720842847852
# Step 2600000/3817199: t = 9652.1s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.765, pumping_energy: 81999.249, charging exergy: 35.46, discharging exergy: 0.00
# Step 2700000, t=9746.4s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.654 m
# convective HT g>s : 0.018537333451619353, th diffusion: -2.8434665118884626e-07, outer loss: 2.6799805596718375e-08, inner loss: 0.0005349720842847852
# Step 2700000/3817199: t = 9746.4s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.858, pumping_energy: 85282.363, charging exergy: 35.46, discharging exergy: 0.00
# Step 2800000, t=9840.7s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.658 m
# convective HT g>s : 0.018464634746932575, th diffusion: -2.8337671209748473e-07, outer loss: 2.698653332090601e-08, inner loss: 0.0005349720842847852
# Step 2800000/3817199: t = 9840.7s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 34.950, pumping_energy: 88574.190, charging exergy: 35.46, discharging exergy: 0.00
# Step 2900000, t=9935.0s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.660 m
# convective HT g>s : 0.01839286951404504, th diffusion: -2.824207646144828e-07, outer loss: 2.7174321761095127e-08, inner loss: 0.0005349720842847852
# Step 2900000/3817199: t = 9935.0s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 35.041, pumping_energy: 91874.651, charging exergy: 35.46, discharging exergy: 0.00
# Step 3000000, t=10029.3s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.663 m
# convective HT g>s : 0.018322018471582182, th diffusion: -2.8147856593238246e-07, outer loss: 2.7363500143288198e-08, inner loss: 0.0005349720842847852
# Step 3000000/3817199: t = 10029.3s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 35.132, pumping_energy: 95183.664, charging exergy: 35.46, discharging exergy: 0.00
# Step 3100000, t=10123.6s → CFL_max=0.61, k1·dt_max=0.00, ΔTs_max=0.00 K @ r=0.666 m
# convective HT g>s : 0.018252062885978547, th diffusion: -2.805498988851674e-07, outer loss: 2.755445908134112e-08, inner loss: 0.0005349720842847852
# Step 3100000/3817199: t = 10123.6s, M_dot = 0.0691
# c_g[0]: 1144.966, Tg[0]: 773.150, T_ref: 298.150
# peak pump power: 35.221, pumping_energy: 98501.152, charging exergy: 35.46, discharging exergy: 0.00
# ...
# Step 300000, t=54282.9s → CFL_max=0.46, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.002 m
# convective HT g>s : -0.011978149986253907, th diffusion: -9.336094318677351e-08, outer loss: -2.7202647481603856e-09, inner loss: 0.00023677739692957105
# Step 300000/3817199: t = 54282.9s, M_dot = -0.0699
# c_g[0]: 1096.082, Tg[0]: 512.438, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 4553.970, charging exergy: 0.00, discharging exergy: 15.11
# Step 400000, t=54377.2s → CFL_max=0.46, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.002 m
# convective HT g>s : -0.011852098031126171, th diffusion: -9.126132742386547e-08, outer loss: -2.7595483421001922e-09, inner loss: 0.00023378643501437667
# Step 400000/3817199: t = 54377.2s, M_dot = -0.0699
# c_g[0]: 1095.584, Tg[0]: 509.780, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 6051.978, charging exergy: 0.00, discharging exergy: 14.92
# Step 500000, t=54471.5s → CFL_max=0.46, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.002 m
# convective HT g>s : -0.011725370598498545, th diffusion: -8.918221123600234e-08, outer loss: -2.8047959017050562e-09, inner loss: 0.00023079959884145988
# Step 500000/3817199: t = 54471.5s, M_dot = -0.0699
# c_g[0]: 1095.086, Tg[0]: 507.127, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 7540.202, charging exergy: 0.00, discharging exergy: 14.72
# Step 600000, t=54565.8s → CFL_max=0.46, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.011598019860342491, th diffusion: -8.712424709921005e-08, outer loss: -2.8559533384956027e-09, inner loss: 0.00022781769510296223
# Step 600000/3817199: t = 54565.8s, M_dot = -0.0699
# c_g[0]: 1094.590, Tg[0]: 504.478, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 9018.766, charging exergy: 0.00, discharging exergy: 14.52
# Step 700000, t=54660.2s → CFL_max=0.46, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.011470097970789055, th diffusion: -8.508806055884359e-08, outer loss: -2.9129697433470972e-09, inner loss: 0.0002248415232630621
# Step 700000/3817199: t = 54660.2s, M_dot = -0.0699
# c_g[0]: 1094.094, Tg[0]: 501.835, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 10487.795, charging exergy: 0.00, discharging exergy: 14.32
# Step 800000, t=54754.5s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.011341657010908666, th diffusion: -8.307424692596247e-08, outer loss: -2.975773129916917e-09, inner loss: 0.00022187187485156774
# Step 800000/3817199: t = 54754.5s, M_dot = -0.0699
# c_g[0]: 1093.600, Tg[0]: 499.198, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 11947.413, charging exergy: 0.00, discharging exergy: 14.13
# Step 900000, t=54848.8s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.011212748933599945, th diffusion: -8.108337567974183e-08, outer loss: -3.0442924952439266e-09, inner loss: 0.0002189095327775492
# Step 900000/3817199: t = 54848.8s, M_dot = -0.0699
# c_g[0]: 1093.106, Tg[0]: 496.568, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 13397.745, charging exergy: 0.00, discharging exergy: 13.93
# Step 1000000, t=54943.1s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.011083425510851955, th diffusion: -7.911598207031985e-08, outer loss: -3.118415783600269e-09, inner loss: 0.00021595527066259972
# Step 1000000/3817199: t = 54943.1s, M_dot = -0.0699
# c_g[0]: 1092.615, Tg[0]: 493.945, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 14838.915, charging exergy: 0.00, discharging exergy: 13.74
# Step 1100000, t=55037.4s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.010953738280006328, th diffusion: -7.717258079233029e-08, outer loss: -3.198054163264043e-09, inner loss: 0.0002130098521966649
# Step 1100000/3817199: t = 55037.4s, M_dot = -0.0699
# c_g[0]: 1092.124, Tg[0]: 491.330, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 16271.047, charging exergy: 0.00, discharging exergy: 13.54
# Step 1200000, t=55131.7s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.010823738492608653, th diffusion: -7.525365843793235e-08, outer loss: -3.2831544650942818e-09, inner loss: 0.000210074030515423
# Step 1200000/3817199: t = 55131.7s, M_dot = -0.0699
# c_g[0]: 1091.636, Tg[0]: 488.724, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 17694.267, charging exergy: 0.00, discharging exergy: 13.35
# Step 1300000, t=55226.0s → CFL_max=0.45, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.010693477065791344, th diffusion: -7.335966740926256e-08, outer loss: -3.3736331699346535e-09, inner loss: 0.0002071485476012234
# Step 1300000/3817199: t = 55226.0s, M_dot = -0.0699
# c_g[0]: 1091.149, Tg[0]: 486.127, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 19108.700, charging exergy: 0.00, discharging exergy: 13.15
# Step 1400000, t=55320.3s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.010563004534012302, th diffusion: -7.149103158792179e-08, outer loss: -3.469360117527038e-09, inner loss: 0.00020423413370773027
# Step 1400000/3817199: t = 55320.3s, M_dot = -0.0699
# c_g[0]: 1090.664, Tg[0]: 483.540, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 20514.469, charging exergy: 0.00, discharging exergy: 12.96
# Step 1500000, t=55414.6s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.01043237100097672, th diffusion: -6.964814961489928e-08, outer loss: -3.5702267786117073e-09, inner loss: 0.0002013315068092189
# Step 1500000/3817199: t = 55414.6s, M_dot = -0.0699
# c_g[0]: 1090.181, Tg[0]: 480.965, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 21911.699, charging exergy: 0.00, discharging exergy: 12.77
# Step 1600000, t=55508.9s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.010301626094437254, th diffusion: -6.783139313115654e-08, outer loss: -3.6761381646853153e-09, inner loss: 0.00019844137207421133
# Step 1600000/3817199: t = 55508.9s, M_dot = -0.0699
# c_g[0]: 1089.700, Tg[0]: 478.400, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 23300.515, charging exergy: 0.00, discharging exergy: 12.58
# Step 1700000, t=55603.3s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.010170818922577412, th diffusion: -6.604110283955819e-08, outer loss: -3.78701009214458e-09, inner loss: 0.00019556442136568801
# Step 1700000/3817199: t = 55603.3s, M_dot = -0.0699
# c_g[0]: 1089.221, Tg[0]: 475.848, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 24681.039, charging exergy: 0.00, discharging exergy: 12.39
# Step 1800000, t=55697.6s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.010039998032670035, th diffusion: -6.42775924774506e-08, outer loss: -3.902705803333549e-09, inner loss: 0.0001927013327653955
# Step 1800000/3817199: t = 55697.6s, M_dot = -0.0699
# c_g[0]: 1088.745, Tg[0]: 473.308, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 26053.396, charging exergy: 0.00, discharging exergy: 12.21
# Step 1900000, t=55791.9s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009909211369971343, th diffusion: -6.254114339099376e-08, outer loss: -4.0230875321739415e-09, inner loss: 0.00018985277012605574
# Step 1900000/3817199: t = 55791.9s, M_dot = -0.0699
# c_g[0]: 1088.271, Tg[0]: 470.781, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 27417.707, charging exergy: 0.00, discharging exergy: 12.02
# Step 2000000, t=55886.2s → CFL_max=0.44, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009778506237853559, th diffusion: -6.083202096986782e-08, outer loss: -4.148059439029881e-09, inner loss: 0.00018701938264864407
# Step 2000000/3817199: t = 55886.2s, M_dot = -0.0699
# c_g[0]: 1087.800, Tg[0]: 468.268, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 28774.097, charging exergy: 0.00, discharging exergy: 11.83
# Step 2100000, t=55980.5s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009647929261907605, th diffusion: -5.915045414488754e-08, outer loss: -4.277525755801615e-09, inner loss: 0.00018420180448682646
# Step 2100000/3817199: t = 55980.5s, M_dot = -0.0699
# c_g[0]: 1087.332, Tg[0]: 465.769, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 30122.687, charging exergy: 0.00, discharging exergy: 11.65
# Step 2200000, t=56074.8s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009517526356083371, th diffusion: -5.749664272680214e-08, outer loss: -4.4112867004229384e-09, inner loss: 0.00018140065437728038
# Step 2200000/3817199: t = 56074.8s, M_dot = -0.0699
# c_g[0]: 1086.866, Tg[0]: 463.285, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 31463.597, charging exergy: 0.00, discharging exergy: 11.47
# Step 2300000, t=56169.1s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009387342685198792, th diffusion: -5.587077340829052e-08, outer loss: -4.549268306723469e-09, inner loss: 0.00017861653529731172
# Step 2300000/3817199: t = 56169.1s, M_dot = -0.0699
# c_g[0]: 1086.403, Tg[0]: 460.817, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 32796.950, charging exergy: 0.00, discharging exergy: 11.29
# Step 2400000, t=56263.4s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.009257422636791284, th diffusion: -5.427299191153368e-08, outer loss: -4.691336457223206e-09, inner loss: 0.00017585003414856553
# Step 2400000/3817199: t = 56263.4s, M_dot = -0.0699
# c_g[0]: 1085.943, Tg[0]: 458.364, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 34122.866, charging exergy: 0.00, discharging exergy: 11.11
# Step 2500000, t=56357.7s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.995 m
# convective HT g>s : -0.00912780979023857, th diffusion: -5.2703428149227674e-08, outer loss: -4.837316377717832e-09, inner loss: 0.0001731017214670147
# Step 2500000/3817199: t = 56357.7s, M_dot = -0.0699
# c_g[0]: 1085.486, Tg[0]: 455.928, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 35441.464, charging exergy: 0.00, discharging exergy: 10.93
# Step 2600000, t=56452.0s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.995 m
# convective HT g>s : -0.008998545622691721, th diffusion: -5.1164445908109436e-08, outer loss: -4.9947319772701835e-09, inner loss: 0.00017037215115995515
# Step 2600000/3817199: t = 56452.0s, M_dot = -0.0699
# c_g[0]: 1085.033, Tg[0]: 453.508, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 36752.862, charging exergy: 0.00, discharging exergy: 10.75
# Step 2700000, t=56546.4s → CFL_max=0.43, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.987 m
# convective HT g>s : -0.00886966729904755, th diffusion: -4.9670336315110314e-08, outer loss: -5.29060055850432e-09, inner loss: 0.00016766186026802917
# Step 2700000/3817199: t = 56546.4s, M_dot = -0.0699
# c_g[0]: 1084.582, Tg[0]: 451.106, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 38057.179, charging exergy: 0.00, discharging exergy: 10.57
# Step 2800000, t=56640.7s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.985 m
# convective HT g>s : -0.00874121548061285, th diffusion: -4.8217511875977554e-08, outer loss: -5.772700529291648e-09, inner loss: 0.00016497136875375215
# Step 2800000/3817199: t = 56640.7s, M_dot = -0.0699
# c_g[0]: 1084.135, Tg[0]: 448.722, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 39354.533, charging exergy: 0.00, discharging exergy: 10.40
# Step 2900000, t=56735.0s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.979 m
# convective HT g>s : -0.008613230356726275, th diffusion: -4.6804495383451646e-08, outer loss: -6.436632933236519e-09, inner loss: 0.00016230117931558387
# Step 2900000/3817199: t = 56735.0s, M_dot = -0.0699
# c_g[0]: 1083.692, Tg[0]: 446.356, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 40645.039, charging exergy: 0.00, discharging exergy: 10.23
# Step 3000000, t=56829.3s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.977 m
# convective HT g>s : -0.008485750934845054, th diffusion: -4.54313085214012e-08, outer loss: -7.286455621125113e-09, inner loss: 0.00015965177722631883
# Step 3000000/3817199: t = 56829.3s, M_dot = -0.0699
# c_g[0]: 1083.252, Tg[0]: 444.008, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 41928.814, charging exergy: 0.00, discharging exergy: 10.05
# Step 3100000, t=56923.6s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.974 m
# convective HT g>s : -0.008358808626813014, th diffusion: -4.407609321895521e-08, outer loss: -8.18030778352857e-09, inner loss: 0.00015702363019719218
# Step 3100000/3817199: t = 56923.6s, M_dot = -0.0699
# c_g[0]: 1082.815, Tg[0]: 441.680, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 43205.971, charging exergy: 0.00, discharging exergy: 9.88
# Step 3200000, t=57017.9s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.002 m
# convective HT g>s : -0.008232473811631115, th diffusion: -4.2700565254495096e-08, outer loss: -8.54470577665568e-09, inner loss: 0.00015441718826552137
# Step 3200000/3817199: t = 57017.9s, M_dot = -0.0699
# c_g[0]: 1082.382, Tg[0]: 439.371, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 44476.625, charging exergy: 0.00, discharging exergy: 9.71
# Step 3300000, t=57112.2s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.002 m
# convective HT g>s : -0.008106775632476254, th diffusion: -4.135039822170041e-08, outer loss: -8.683171912465775e-09, inner loss: 0.0001518328837065467
# Step 3300000/3817199: t = 57112.2s, M_dot = -0.0699
# c_g[0]: 1081.953, Tg[0]: 437.082, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 45740.888, charging exergy: 0.00, discharging exergy: 9.55
# Step 3400000, t=57206.5s → CFL_max=0.42, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=1.001 m
# convective HT g>s : -0.007981737891566344, th diffusion: -4.003438484062993e-08, outer loss: -8.813373372253756e-09, inner loss: 0.00014927113096826184
# Step 3400000/3817199: t = 57206.5s, M_dot = -0.0699
# c_g[0]: 1081.527, Tg[0]: 434.813, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 46998.873, charging exergy: 0.00, discharging exergy: 9.38
# Step 3500000, t=57300.8s → CFL_max=0.41, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.007857392853709141, th diffusion: -3.874941466620324e-08, outer loss: -8.96108854107548e-09, inner loss: 0.0001467323266294026
# Step 3500000/3817199: t = 57300.8s, M_dot = -0.0699
# c_g[0]: 1081.106, Tg[0]: 432.565, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 48250.689, charging exergy: 0.00, discharging exergy: 9.22
# Step 3600000, t=57395.1s → CFL_max=0.41, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.007733774023975596, th diffusion: -3.749344406738605e-08, outer loss: -9.116065337188531e-09, inner loss: 0.00014421684937917744
# Step 3600000/3817199: t = 57395.1s, M_dot = -0.0699
# c_g[0]: 1080.688, Tg[0]: 430.337, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 49496.447, charging exergy: 0.00, discharging exergy: 9.06
# Step 3700000, t=57489.5s → CFL_max=0.41, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.007610913800688127, th diffusion: -3.626581865016406e-08, outer loss: -9.273051848364577e-09, inner loss: 0.00014172506001913074
# Step 3700000/3817199: t = 57489.5s, M_dot = -0.0699
# c_g[0]: 1080.275, Tg[0]: 428.131, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 50736.256, charging exergy: 0.00, discharging exergy: 8.90
# Step 3800000, t=57583.8s → CFL_max=0.41, k1·dt_max=0.00, ΔTs_max=-0.00 K @ r=0.998 m
# convective HT g>s : -0.007488843357517347, th diffusion: -3.50662760551213e-08, outer loss: -9.431118074882272e-09, inner loss: 0.00013925730148518965
# Step 3800000/3817199: t = 57583.8s, M_dot = -0.0699
# c_g[0]: 1079.865, Tg[0]: 425.946, T_ref: 303.150
# peak pump power: 16.257, pumping_energy: 51970.222, charging exergy: 0.00, discharging exergy: 8.74
# total_pumping_kWh: 0.35993485713000245, global_peak_pump_kW: 0.04225897947413096, total_charge_ex_kWh: 225.5752607364619, total_discharge_ex_kWh: 159.56247828355492

# %%
stored_energy_kWh = sim_data_energy['Stored_Energy_kWh'].to_numpy()
charge_exergy_kWh = sim_data_energy['Charge_Exergy_kWh'].to_numpy()
discharge_exergy_kWh = sim_data_energy['Discharge_Exergy_kWh'].to_numpy()
energy_charged_kWh = sim_data_energy['Energy_Charged_kWh'].to_numpy()
energy_discharged_kWh = sim_data_energy['Energy_Discharged_kWh'].to_numpy()

# %%
print(f'total_pumping_kWh: {total_pumping_kWh}, global_peak_pump_kW: {global_peak_pump_kW}, total_charge_ex_kWh: {total_charge_ex_kWh}, total_discharge_ex_kWh: {total_discharge_ex_kWh}')
# Out:
# total_pumping_kWh: 0.35993485713000245, global_peak_pump_kW: 0.04225897947413096, total_charge_ex_kWh: 225.5752607364619, total_discharge_ex_kWh: 159.56247828355492

# %%
gas_temp_C = sim_data_energy['Gas Temp (C)'].to_numpy()
np.min(gas_temp_C)
# Out:
# np.float64(152.42287867044644)

# %%
total_discharge_ex_kWh/total_charge_ex_kWh
# Out:
# np.float64(0.7073580576283617)

# %%
out_dir = r"C:\\Users\\tljohn\\Desktop\\RPB Micmaq\\geometry simulations\\official\\1-2"
os.makedirs(out_dir, exist_ok=True)

sim_data.to_csv(os.path.join(out_dir, 'sim_data_full.csv'), index=False)

sim_data_energy.to_csv(os.path.join(out_dir, 'exergy_history.csv'), index=False)

# %%
# 1) Thermocline profiles
if isinstance(sim_data, list):
    sim_df = pd.concat(sim_data, ignore_index=True)
else:
    sim_df = sim_data.copy()

profiles_path = os.path.join(out_dir, "thermocline_profiles.csv")
sim_df.to_csv(profiles_path, index=False)
print(f"Wrote profiles to {profiles_path}")

# 2) Time history
numNodes = len(NodesToTraceInTime)
cols = ["time_sec"]
for j in range(numNodes):
    cols += [f"Tg_r{j}", f"Ts_r{j}"]

time_df = pd.DataFrame(timeHistory, columns=cols)
history_path = os.path.join(out_dir, "thermocline_timehistory.csv")
time_df.to_csv(history_path, index=False)
print(f"Wrote time history to {history_path}")

# 3) Geometry summary
ratio_str = f"1:{(rR/B):.2f}"

eta_ex          = np.abs(total_discharge_ex_kWh/total_charge_ex_kWh)*100
print(eta_ex)
summary = pd.DataFrame([{
    "Ratio"          : ratio_str,
    "AvgDeltaP_Pa"   : dp_avg,
    "Max Pumping Power [kW]"       : global_peak_pump_kW,
    "Stored_MJ"      : total_stored_energy  / 1e6,
    "Insulation_m"   : optimized_insul_thickness,
    "Pump_Energy_kWh" : total_pumping_kWh,
    "Charge_ex_kWh"   : total_charge_ex_kWh, 
    "Discharge_ex_kWh" : total_discharge_ex_kWh,
    "Eta exergy"     : eta_ex
}])
summary_path = os.path.join(out_dir, "geometry_summary.csv")
summary.to_csv(summary_path, index=False)
print(f"Wrote summary to {summary_path}")
# Out:
# Wrote profiles to C:\\Users\\tljohn\\Desktop\\RPB Micmaq\\geometry simulations\\official\\1-2\thermocline_profiles.csv
# Wrote time history to C:\\Users\\tljohn\\Desktop\\RPB Micmaq\\geometry simulations\\official\\1-2\thermocline_timehistory.csv
# 70.73580576283616
# Wrote summary to C:\\Users\\tljohn\\Desktop\\RPB Micmaq\\geometry simulations\\official\\1-2\geometry_summary.csv

# %%
# ── CONFIG ─────────────────────────────────────────────────────────────────
OUT_DIR      = r"C:\Users\tljohn\Desktop\RPB Micmaq\geometry simulations\official\1-2"

PROFILES_CSV = "thermocline_profiles.csv"
HISTORY_CSV  = "thermocline_timehistory.csv"

SUMMARY_CSV  = "geometry_summary.csv"

# BASE_TIME = tea_day_spring.index[11].to_pydatetime()
BASE_TIME = datetime(2033, 3, 20, 11, 0, 0)

# ── LOAD CSVs ──────────────────────────────────────────────────────────────
profiles_path = os.path.join(OUT_DIR, PROFILES_CSV)
history_path  = os.path.join(OUT_DIR, HISTORY_CSV)
summary_path  = os.path.join(OUT_DIR, SUMMARY_CSV)

sim_df   = pd.read_csv(profiles_path)
time_df  = pd.read_csv(history_path)
summary  = pd.read_csv(summary_path)

# Drop the placeholder (time_sec == 0) rows
time_df = time_df[time_df["time_sec"] > 0].copy()

time_df["time_dt"] = time_df["time_sec"].apply(lambda s: BASE_TIME + timedelta(seconds=s))

# ── 2) FIGURE 1: Temperature vs. Radius ────────────────────────────────────
plt.figure(figsize=(12,8))
plt.xlabel("Radius (m)")
plt.ylabel("Temperature (°C)")
plt.grid(True)
used = set()
for phase in sorted(sim_df["Phase"].unique()):
    dfp = sim_df[sim_df["Phase"] == phase]
    color = dfp["Line_Color"].iloc[0]
    rvals = dfp["Radius_m"]; Tvals = dfp["Temperature_C"]
    plt.plot(rvals, Tvals, ":", lw=3, color=color)
    grad = np.abs(np.gradient(Tvals, rvals))
    idx = np.argmax(grad)
    x,y = rvals.values[idx], Tvals.values[idx]
    dx,dy = 0.02,1.0
    while (round(x,3),round(y,3)) in used:
        x+=dx; y+=dy
    used.add((round(x,3),round(y,3)))
    plt.annotate(f"Hour {int(phase)+1}", xy=(rvals.values[idx],Tvals.values[idx]),
                 xytext=(x,y), textcoords="data", fontsize=10, ha="left",
                 arrowprops=dict(arrowstyle="->", lw=0.5))
plt.tight_layout(); plt.show()

# ── 3) FIGURE 2: Temperature Slope vs. Radius ───────────────────────────────
plt.figure(figsize=(12,8))
plt.xlabel("Radius (m)")
plt.ylabel("dT/dr (°C/m)")
plt.grid(True)
used = set()
for phase in sorted(sim_df["Phase"].unique()):
    dfp = sim_df[sim_df["Phase"] == phase]
    color = dfp["Line_Color"].iloc[0]
    rvals = dfp["Radius_m"]; Tvals = dfp["Temperature_C"]
    slope = np.gradient(Tvals, rvals)
    plt.plot(rvals, slope, ":", lw=3, color=color)
    idx = np.argmax(np.abs(slope))
    x,y = rvals.values[idx], slope[idx]
    dx,dy = 0.02,1.0
    while (round(x,3),round(y,3)) in used:
        x+=dx; y+=dy
    used.add((round(x,3),round(y,3)))
    plt.annotate(f"Hour {int(phase)+1}", xy=(rvals.values[idx],slope[idx]),
                 xytext=(x,y), textcoords="data", fontsize=10, ha="left",
                 arrowprops=dict(arrowstyle="->", lw=0.5))
plt.tight_layout(); plt.show()

# ── 4) FIGURE 3: Temperature vs. Time with Hourly Color‑Coded Lines ────────
plt.figure(figsize=(14,8))
plt.ylabel("Temperature (°C)")
plt.grid(True)
ax = plt.gca()
ax.xaxis_date(); ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
# plot each node
Ts_cols = [c for c in time_df.columns if c.startswith("Ts_r")]
for col in Ts_cols:
    radius = col.split("_")[1]
    trace = time_df[col] - 273.15
    valid = (trace > -50) & np.isfinite(trace)
    ax.plot(time_df["time_dt"][valid], trace[valid], label=radius)
# vertical hour lines
t0 = BASE_TIME.replace(minute=0,second=0)
t1 = time_df["time_dt"].max().replace(minute=0,second=0)+timedelta(hours=1)
hours = list(pd.date_range(t0, t1, freq="H"))
for t in hours:
    secs = (t - BASE_TIME).total_seconds()
    idx = np.searchsorted(phase_change_times, secs, side="right")-1
    idx = max(min(idx, len(simHist)-1),0)
    Mdot = simHist[idx][0]
    color = 'r' if Mdot>0 else 'g' if Mdot==0 else 'b'
    phase = 'Charge' if Mdot>0 else 'Hold' if Mdot==0 else 'Discharge'
    handles, labels = ax.get_legend_handles_labels()
    ax.axvline(t, color=color, linestyle="--", alpha=0.7,
               label=phase if phase not in labels else "")
# plt.legend(title="Node / Phase", loc="upper right")
plt.tight_layout(); plt.show()

# ── 5) FIGURE 4: ΔP, Pump Power, Parasitic Losses, Insulation Cost & Exergy ──
df_sum    = summary  # pd.read_csv(summary_path)
ratios    = df_sum["Ratio"].values
dp_vals   = df_sum["AvgDeltaP_Pa"].values
pump_vals = df_sum["Max Pumping Power [kW]"].values
parasitic = df_sum["Pump_Energy_kWh"].values     
ins_m     = df_sum["Insulation_m"].values
exergy_k  = df_sum["Eta exergy"].values
 
hole_radius = 0.0254  # m
outer_area  = np.pi*(rR/2)**2 - np.pi*hole_radius**2
unit_cost   = 58.5    # $/m³ super-wool
ins_costs   = ins_m * outer_area * unit_cost

x = np.arange(len(ratios))
fig, axs = plt.subplots(1, 5, figsize=(25, 5), sharex=True)

# ΔP
axs[0].bar(x, dp_vals, color='C0')
axs[0].set_title("Avg ΔP")
axs[0].set_ylabel("ΔP (Pa)")
for xi, h in zip(x, dp_vals):
    axs[0].text(xi, h, f"{h:.0f}", ha="center", va="bottom", fontsize=8)

# Max Pump Power
axs[1].bar(x, pump_vals, color='C1')
axs[1].set_title("Max Pump Power")
axs[1].set_ylabel("Power (kW)")
for xi, h in zip(x, pump_vals):
    axs[1].text(xi, h, f"{h:.1f}", ha="center", va="bottom", fontsize=8)

# Parasitic Pump Losses
total_seconds = phase_change_times[-1]
total_hours   = total_seconds / 3600

axs[2].bar(x, parasitic, color='C4')
axs[2].set_title(f"Parasitic pump losses in {total_hours:.1f} h period")
axs[2].set_ylabel("Energy (kWh)")
for xi, h in zip(x, parasitic):
    axs[2].text(xi, h, f"{h:.2f}", ha="center", va="bottom", fontsize=8)

# Insulation Cost
axs[3].bar(x, ins_costs, color='C2')
axs[3].set_title("Insulation Cost")
axs[3].set_ylabel("Cost ($)")
for xi, h in zip(x, ins_costs):
    axs[3].text(xi, h, f"${h:.0f}", ha="center", va="bottom", fontsize=8)

# Exergy Stored
axs[4].bar(x, exergy_k, color='C3')
axs[4].set_title("Exergy Stored")
axs[4].set_ylabel("Exergy (kWh)")
for xi, h in zip(x, exergy_k):
    axs[4].text(xi, h, f"{h:.1f}", ha="center", va="bottom", fontsize=8)

# shared x-axis
for ax in axs:
    ax.set_xticks(x)
    ax.set_xticklabels(ratios, rotation=0, ha="center")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tljohn\AppData\Local\Temp\ipykernel_12848\11192144.py:88: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hours = list(pd.date_range(t0, t1, freq="H"))
# posx and posy should be finite values
# posx and posy should be finite values
